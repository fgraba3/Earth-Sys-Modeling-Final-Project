# %% [markdown]
# **Equations:** There are a variety of different physical processes that are considered by this model; including shortwave and longwave radiation, flux of latent and sensible heat, as well as evaporation determined by the mass transfer technique of Harbeck [1962].
#
# **Equation 1:** The governing equation of the model incorporates all parameters that go into calculating evaporation, including: T – temperature(℃); t – time(day); $A(z)$- lake area at depth z (m2); $z$ – depth(m); $Km$ – molecular diffusion of water($m^2/d$); $K(z, t)$ - eddy diffusivity of water (m2d); Cw – volumetric heat capacity of water($Jm^{−3}℃^{−1}$); $𝜙$ – a heat source term.
#
# **Equation 2:** $𝜙$ the heat source term (Dake & Harleman 1969) is a measure of subsurface heating in a lake based on the absorption of penetrating solar radiation, based on Beer’s law. Parameters involved in this equation include:  $β$ - percent of shortwave radiation absorbed in surface layer; $K^∗$ - net shortwave radiation at the water surface; $𝜂$ – light extinction coefficient for water; $z$ - depth
#
# **Equation 3:** The upper boundary (surface) boundary condition is set and defined by a heat energy balance at the lake’s surface (3) (Hostetler & Bartlein 1990). The net long-wave radiation from the atmosphere is $L^{∗}_d$, long-wave radiation emitted from the lake is Lu,the flux of latent heat is $Qe$, and the flux of sensible heat is $Qh$ with variables in units of $(W/m^{2})$. The upper boundary condition considers all energy absorbed in and radiated from the lake’s surface.
#
# **Equation 4:** The lower boundary condition sets the boundary for an insulated lake bottom. The equation considers the molecular diffusion of water
# km plus eddy diffusivity $K(z,t)$ multiplied by the change in temperature $(T)$ with respect to lake depth $(m)$ $∂T/∂z$.
#
#
# ![image.png](data:image/png;base64,...)
